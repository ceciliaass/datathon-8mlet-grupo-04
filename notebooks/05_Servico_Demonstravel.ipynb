# %% [markdown]
# # Etapa 5 - Servico ou Interface Demonstravel
#
# Testar a recomendacao recebendo os dados de um cliente e retornando a oferta escolhida.

# %%
from pathlib import Path

model_path = Path('../models')
print(f'Diretorio de modelos: {model_path.resolve()}')
print('Proxima implementacao: chamada ao servico ou interface de recomendacao.')
