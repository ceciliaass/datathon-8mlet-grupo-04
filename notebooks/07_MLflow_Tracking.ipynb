# %% [markdown]
# # Etapa 7 - Ciclo de Vida MLOps
#
# Registrar parametros, metricas e artefatos do baseline e do modelo adaptativo com MLflow.

# %%
try:
    import mlflow
    print(f'MLflow disponivel: {mlflow.__version__}')
except ImportError:
    print('Instale MLflow com: pip install mlflow')

print('Proxima implementacao: runs, parametros, metricas e artefatos.')
