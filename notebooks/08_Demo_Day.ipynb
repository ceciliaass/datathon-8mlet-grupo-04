# %% [markdown]
# # Etapa 8 - Apresentacao Final
#
# Roteiro executavel para demonstrar o problema, o modelo, a recomendacao e os resultados em ate cinco minutos.

# %%
from pathlib import Path

artifacts = [
    Path('../data/processed/bank-marketing_eda/bank_marketing_tratado.csv'),
    Path('../data/processed/bank-marketing_eda/bandit_metrics.json')
]
for artifact in artifacts:
    print(f'{artifact}: {"OK" if artifact.exists() else "AUSENTE"}')
